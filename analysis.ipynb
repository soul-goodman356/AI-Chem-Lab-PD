# %% [markdown]
# # Analysis: t-tests (gain), effect sizes, and forest plot
# This notebook loads `data/summary/summary_tidy_*.csv`, computes gain-based standardized effect sizes (Cohen's d with 95% CI),
# reports the two-group *t* statistic on gains, and reproduces **Figure 1 (forest plot)**.
#
# **Note**: p-values are not computed to avoid extra dependencies; the *t* value and df are reported. You can install `scipy` for exact p-values if needed.

# %%
# %cd code
import sys, importlib
import analysis as A
A.main(r=0.5)  # assumed pre-post correlation
print('Done. See ./results for outputs.')
